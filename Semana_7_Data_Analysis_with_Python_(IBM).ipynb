# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-Emerson-JRM/blob/main/Semana_7_Data_Analysis_with_Python_(IBM).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Ciencia y analítica de datos (Gpo 10)**
#
#
# #            **01/Nov/2022 **

# %% [markdown]
# ```
#
# ```
#
# # Semana 7: Data Analysis with Python (IBM)

# %% [markdown]
# # **Emerson Jonathan Rincón Morales**     # **A01793814**

# %% [markdown]
# link to giHub:    https://github.com/PosgradoMNA/actividades-de-aprendizaje-Emerson-JRM/blob/main/Actividad%20Semanal%20--%206%2C%20visualizaci%C3%B3n.ipynb

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
